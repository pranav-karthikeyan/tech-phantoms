# %%
dima806/facial_emotions_image_detection
CynthiaCR/emotions_classifier

# %%
#!conda create --yes --name myenv python=3.9
#!conda activate myenv
#!conda install -y -c conda-forge \
#    accelerate==0.23.0 \
#    validators==0.22.0 \
#    diffusers==0.18.2 \
#    transformers==4.32.1 \
#    pillow \
#    ipywidgets \
#    ipython
#import sys
#!{sys.executable} -m pip install invisible-watermark
#!conda list
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 24.1.2
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/u2a67f3b0c6b1806f806f7159018a426/.conda/envs/myenv
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.2.1              |       hd590300_1         2.7 MB  intel
#     ------------------------------------------------------------
#                                            Total:         2.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      intel/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      intel/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              intel/linux-64::bzip2-1.0.8-hb9a14ef_9
#   ca-certificates    intel/linux-64::ca-certificates-2024.2.2-hbcca054_0
#   intelpython        intel/linux-64::intelpython-2024.1.0-0
#   libffi             intel/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          intel/linux-64::libgcc-ng-13.2.0-h807b86a_5
#   libgomp            intel/linux-64::libgomp-13.2.0-h807b86a_5
#   libnsl             intel/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          intel/linux-64::libsqlite-3.45.1-h2797004_0
#   libstdcxx-ng       intel/linux-64::libstdcxx-ng-13.2.0-h7e041cc_5
#   libuuid            intel/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libzlib            intel/linux-64::libzlib-1.2.13-hd590300_5
#   ncurses            intel/linux-64::ncurses-6.4-h59595ed_2
#   openssl            intel/linux-64::openssl-3.2.1-hd590300_1
#   pip                intel/noarch::pip-24.0-pyhd8ed1ab_0
#   python             intel/linux-64::python-3.9.18-h4499717_0
#   readline           intel/linux-64::readline-8.2-h8228510_1
#   setuptools         intel/noarch::setuptools-69.1.0-pyhd8ed1ab_1
#   tk                 intel/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tzdata             intel/noarch::tzdata-2024a-h0c530f3_0
#   wheel              intel/noarch::wheel-0.42.0-pyhd8ed1ab_0
#   xz                 intel/linux-64::xz-5.2.8-h5eee18b_0
#
#
#
# Downloading and Extracting Packages:
# python-3.9.18        | 25.5 MB   |                                       |   0%
# openssl-3.2.1        | 2.7 MB    |                                       |   0%
#
# libffi-3.4.2         | 57 KB     |                                       |   0%
#
#
# _openmp_mutex-4.5    | 23 KB     |                                       |   0%
#
#
#
# _libgcc_mutex-0.1    | 3 KB      |                                       |   0%
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
#
#
# _openmp_mutex-4.5    | 23 KB     | ##################################### | 100%
#
# libffi-3.4.2         | 57 KB     | ##################################### | 100%
#
# libffi-3.4.2         | 57 KB     | ##################################### | 100%
# openssl-3.2.1        | 2.7 MB    | 2                                     |   1%
# openssl-3.2.1        | 2.7 MB    | #2                                    |   3%
# openssl-3.2.1        | 2.7 MB    | ##5                                   |   7%
# openssl-3.2.1        | 2.7 MB    | ###8                                  |  10%
# openssl-3.2.1        | 2.7 MB    | #####5                                |  15%
# openssl-3.2.1        | 2.7 MB    | ######7                               |  18%
# openssl-3.2.1        | 2.7 MB    | ########4                             |  23%
# openssl-3.2.1        | 2.7 MB    | #########9                            |  27%
# openssl-3.2.1        | 2.7 MB    | ###########6                          |  31%
# openssl-3.2.1        | 2.7 MB    | #############3                        |  36%
# openssl-3.2.1        | 2.7 MB    | ###############                       |  41%
# openssl-3.2.1        | 2.7 MB    | ################7                     |  45%
# openssl-3.2.1        | 2.7 MB    | ##################6                   |  50%
# openssl-3.2.1        | 2.7 MB    | ####################                  |  54%
# openssl-3.2.1        | 2.7 MB    | #####################7                |  59%
# openssl-3.2.1        | 2.7 MB    | #######################6              |  64%
# openssl-3.2.1        | 2.7 MB    | #########################3            |  69%
# openssl-3.2.1        | 2.7 MB    | ###########################5          |  74%
# openssl-3.2.1        | 2.7 MB    | #############################4        |  79%
# openssl-3.2.1        | 2.7 MB    | ###############################3      |  85%
# openssl-3.2.1        | 2.7 MB    | #################################2    |  90%
# openssl-3.2.1        | 2.7 MB    | ###################################1  |  95%
# openssl-3.2.1        | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# Collecting package metadata (current_repodata.json): - WARNING conda.models.version:get_matcher(562): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): \ WARNING conda.models.version:get_matcher(562): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(562): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(562): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 24.1.2
#   latest version: 24.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/intel/oneapi/intelpython
#
#   added / updated specs:
#     - accelerate==0.23.0
#     - diffusers==0.18.2
#     - ipython
#     - ipywidgets
#     - pillow
#     - transformers==4.32.1
#     - validators==0.22.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.2.1              |       hd590300_1         2.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   accelerate         conda-forge/noarch::accelerate-0.23.0-pyhd8ed1ab_0
#   aiohttp            conda-forge/linux-64::aiohttp-3.9.3-py39hd1e30aa_1
#   aiosignal          conda-forge/noarch::aiosignal-1.3.1-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.3-pyhd8ed1ab_0
#   attrs              conda-forge/noarch::attrs-23.2.0-pyh71513ae_0
#   aws-c-auth         conda-forge/linux-64::aws-c-auth-0.7.7-h4faf3ed_1
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.6.9-h3b91eb8_1
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.9.8-hd590300_0
#   aws-c-compression  conda-forge/linux-64::aws-c-compression-0.2.17-hfd9eb17_6
#   aws-c-event-stream conda-forge/linux-64::aws-c-event-stream-0.3.2-h1fff966_7
#   aws-c-http         conda-forge/linux-64::aws-c-http-0.7.14-hc86c171_2
#   aws-c-io           conda-forge/linux-64::aws-c-io-0.13.36-hc23c90e_0
#   aws-c-mqtt         conda-forge/linux-64::aws-c-mqtt-0.9.10-hba57965_1
#   aws-c-s3           conda-forge/linux-64::aws-c-s3-0.4.1-hfadff92_0
#   aws-c-sdkutils     conda-forge/linux-64::aws-c-sdkutils-0.1.12-hfd9eb17_5
#   aws-checksums      conda-forge/linux-64::aws-checksums-0.1.17-hfd9eb17_5
#   aws-crt-cpp        conda-forge/linux-64::aws-crt-cpp-0.24.7-h97e63c7_6
#   aws-sdk-cpp        conda-forge/linux-64::aws-sdk-cpp-1.11.182-h8beafcf_7
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   datasets           conda-forge/noarch::datasets-2.18.0-pyhd8ed1ab_0
#   diffusers          conda-forge/noarch::diffusers-0.18.2-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.8-pyhd8ed1ab_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.2.0-pyhd8ed1ab_2
#   filelock           conda-forge/noarch::filelock-3.13.3-pyhd8ed1ab_0
#   frozenlist         conda-forge/linux-64::frozenlist-1.4.1-py39hd1e30aa_0
#   fsspec             conda-forge/noarch::fsspec-2024.2.0-pyhca7485f_0
#   gflags             conda-forge/linux-64::gflags-2.2.2-he1b5a44_1004
#   glog               conda-forge/linux-64::glog-0.6.0-h6f12383_0
#   huggingface_hub    conda-forge/noarch::huggingface_hub-0.22.1-pyhd8ed1ab_0
#   jinja2             conda-forge/noarch::jinja2-3.1.3-pyhd8ed1ab_0
#   libabseil          conda-forge/linux-64::libabseil-20230802.1-cxx17_h59595ed_0
#   libarrow           conda-forge/linux-64::libarrow-12.0.1-hd1ba8c9_26_cpu
#   libcrc32c          conda-forge/linux-64::libcrc32c-1.1.2-h9c3ff4c_0
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libgoogle-cloud    conda-forge/linux-64::libgoogle-cloud-2.12.0-h5206363_4
#   libgrpc            conda-forge/linux-64::libgrpc-1.59.2-hd6c4280_0
#   libnl              conda-forge/linux-64::libnl-3.9.0-hd590300_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-4.24.4-hf27288f_0
#   libre2-11          conda-forge/linux-64::libre2-11-2023.09.01-h7a70373_1
#   libthrift          conda-forge/linux-64::libthrift-0.19.0-hb90f79a_1
#   libutf8proc        conda-forge/linux-64::libutf8proc-2.8.0-h166bdaf_0
#   libuv              conda-forge/linux-64::libuv-1.48.0-hd590300_0
#   markupsafe         conda-forge/linux-64::markupsafe-2.1.5-py39hd1e30aa_0
#   mkl-include        conda-forge/linux-64::mkl-include-2024.0.0-ha957f24_49657
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multidict          conda-forge/linux-64::multidict-6.0.5-py39hd1e30aa_0
#   multiprocess       conda-forge/linux-64::multiprocess-0.70.16-py39hd1e30aa_0
#   networkx           conda-forge/noarch::networkx-3.2.1-pyhd8ed1ab_0
#   orc                conda-forge/linux-64::orc-1.9.0-h4b38347_4
#   pyarrow            conda-forge/linux-64::pyarrow-12.0.1-py39h6925388_26_cpu
#   pyarrow-hotfix     conda-forge/noarch::pyarrow-hotfix-0.6-pyhd8ed1ab_0
#   python-xxhash      conda-forge/linux-64::python-xxhash-3.4.1-py39hd1e30aa_0
#   pytorch            intel/linux-64::pytorch-2.1.0-py39_xpu_0
#   rdma-core          conda-forge/linux-64::rdma-core-50.0-hd3aeb46_1
#   re2                conda-forge/linux-64::re2-2023.09.01-h7f4b329_1
#   regex              conda-forge/linux-64::regex-2023.12.25-py39hd1e30aa_0
#   s2n                conda-forge/linux-64::s2n-1.3.56-h06160fa_0
#   sacremoses         conda-forge/noarch::sacremoses-0.0.53-pyhd8ed1ab_0
#   safetensors        conda-forge/linux-64::safetensors-0.4.2-py39h9fdd4d6_0
#   snappy             conda-forge/linux-64::snappy-1.1.10-h9fff704_0
#   sympy              conda-forge/noarch::sympy-1.12-pyh04b8f61_3
#   tokenizers         conda-forge/linux-64::tokenizers-0.13.3-py39h585fa2d_0
#   transformers       conda-forge/noarch::transformers-4.32.1-pyhd8ed1ab_0
#   ucx                conda-forge/linux-64::ucx-1.15.0-h11edf95_7
#   validators         conda-forge/noarch::validators-0.22.0-pyhd8ed1ab_0
#   xxhash             conda-forge/linux-64::xxhash-0.8.2-hd590300_0
#   yarl               conda-forge/linux-64::yarl-1.9.4-py39hd1e30aa_0
#
# The following packages will be UPDATED:
#
#   ipython                               8.12.0-pyh41d4057_0 --> 8.18.1-pyh707e725_3
#   openssl                                  3.2.1-hd590300_0 --> 3.2.1-hd590300_1
#   pillow                intel::pillow-10.0.1-py39had0adad_2 --> conda-forge::pillow-10.2.0-py39had0adad_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /opt/intel/oneapi/intelpython
#   uid: 19896
#   gid: 100
#
#
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -uggingface-hub (/home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (/home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages)
# Requirement already satisfied: invisible-watermark in /home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: Pillow>=6.0.0 in /opt/intel/oneapi/intelpython/envs/pytorch-gpu/lib/python3.9/site-packages (from invisible-watermark) (10.0.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages (from invisible-watermark) (1.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /opt/intel/oneapi/intelpython/envs/pytorch-gpu/lib/python3.9/site-packages (from invisible-watermark) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages (from invisible-watermark) (4.9.0.80)
# Requirement already satisfied: torch in /home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages (from invisible-watermark) (1.9.0)
# Requirement already satisfied: typing-extensions in /home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages (from torch->invisible-watermark) (4.10.0)
# WARNING: Ignoring invalid distribution -uggingface-hub (/home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (/home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (/home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (/home/u2a67f3b0c6b1806f806f7159018a426/.local/lib/python3.9/site-packages)
# # packages in environment at /opt/intel/oneapi/intelpython:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    intel
# _openmp_mutex             4.5                       2_gnu    intel
# archspec                  0.2.2              pyhd8ed1ab_0    conda-forge
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# boltons                   23.0.0             pyhd8ed1ab_0    conda-forge
# brotli                    1.1.0                hd590300_1    intel
# brotli-bin                1.1.0                hd590300_1    intel
# brotli-python             1.1.0            py39h3d6467e_1    intel
# bzip2                     1.0.8                h7f98852_4    intel
# c-ares                    1.20.1               hd590300_0    intel
# ca-certificates           2024.2.2             hbcca054_0    conda-forge
# certifi                   2024.2.2           pyhd8ed1ab_0    conda-forge
# cffi                      1.16.0           py39h7a31438_0    intel
# charset-normalizer        3.3.0              pyhd8ed1ab_0    intel
# colorama                  0.4.6              pyhd8ed1ab_0    intel
# comm                      0.2.1              pyhd8ed1ab_0    conda-forge
# conda                     24.1.2           py39hf3d152e_0    conda-forge
# conda-libmamba-solver     23.11.1            pyhd8ed1ab_0    conda-forge
# conda-package-handling    2.2.0              pyh38be061_0    intel
# conda-package-streaming   0.9.0              pyhd8ed1ab_0    intel
# contourpy                 1.0.7            py39h4b4f3f3_0    intel
# cryptography              41.0.4           py39hd4f0224_0    intel
# cycler                    0.12.1             pyhd8ed1ab_0    intel
# daal4py                   2024.0.0        py39_intel_49530    intel
# dal                       2024.0.0            intel_49530    intel
# debugpy                   1.8.1            py39h3d6467e_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# distro                    1.9.0              pyhd8ed1ab_0    conda-forge
# dpcpp-cpp-rt              2024.0.0            intel_49795    intel
# dpcpp-llvm-spirv          2024.0.0        py39haaad0e5_49588    intel
# dpcpp_cpp_rt              2024.0.0            intel_49795    intel
# dpctl                     0.15.0          py39h9daa3b9_42    intel
# dpnp                      0.13.0          py39ha1a3bb5_170    intel
# executing                 2.0.1              pyhd8ed1ab_0    conda-forge
# fmt                       10.1.1               h00ab1b0_1    conda-forge
# fonttools                 4.39.4           py39hd1e30aa_0    intel
# fortran_rt                2024.0.0            intel_49795    intel
# freetype                  2.12.1               h267a509_2    intel
# icc_rt                    2024.0.0            intel_49795    intel
# icu                       73.2                 h59595ed_0    intel
# idna                      3.4                pyhd8ed1ab_0    intel
# importlib-metadata        7.0.1              pyha770c72_0    conda-forge
# importlib-resources       5.12.0             pyhd8ed1ab_0    intel
# importlib_metadata        7.0.1                hd8ed1ab_0    conda-forge
# importlib_resources       5.12.0             pyhd8ed1ab_0    intel
# intel-cmplr-lib-rt        2024.0.0            intel_49795    intel
# intel-cmplr-lic-rt        2024.0.0            intel_49795    intel
# intel-fortran-rt          2024.0.0            intel_49795    intel
# intel-opencl-rt           2024.0.0            intel_49795    intel
# intel-openmp              2024.0.0            intel_49795    intel
# intelpython               2024.0.0                      0    intel
# ipp                       2021.10.0             intel_555    intel
# ipykernel                 6.29.2             pyhd33586a_0    conda-forge
# ipython                   8.12.0             pyh41d4057_0    conda-forge
# ipywidgets                8.1.2              pyhd8ed1ab_0    conda-forge
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# joblib                    1.3.2              pyhd8ed1ab_0    intel
# jsonpatch                 1.33               pyhd8ed1ab_0    intel
# jsonpointer               2.4              py39hf3d152e_3    intel
# jupyter_client            8.6.0              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.1            py39hf3d152e_0    conda-forge
# jupyterlab_widgets        3.0.10             pyhd8ed1ab_0    conda-forge
# keyutils                  1.6.1                h166bdaf_1    intel
# kiwisolver                1.4.5            py39h7633fee_1    intel
# krb5                      1.21.2               h659d440_0    intel
# lcms2                     2.16                 hb7c19ff_0    conda-forge
# lerc                      4.0.0                h27087fc_1    intel
# level-zero                1.14.0               h00ab1b0_2    intel
# libarchive                3.7.2                h039dbb9_0    conda-forge
# libbrotlicommon           1.1.0                hd590300_1    intel
# libbrotlidec              1.1.0                hd590300_1    intel
# libbrotlienc              1.1.0                hd590300_1    intel
# libcurl                   8.4.0                hca28451_0    intel
# libdeflate                1.19                 hd590300_0    intel
# libedit                   3.1.20221030         h5eee18b_1    intel
# libev                     4.33                 h516909a_2    intel
# libffi                    3.4.2                h7f98852_5    intel
# libgcc-ng                 13.2.0               h807b86a_2    intel
# libgomp                   13.2.0               h807b86a_2    intel
# libiconv                  1.17                 h166bdaf_0    intel
# libjpeg-turbo             3.0.0                hd590300_1    intel
# libllvm14                 14.0.6               hcd5def8_4    intel
# libmamba                  1.5.4                had39da4_0    conda-forge
# libmambapy                1.5.4            py39h10defb6_0    conda-forge
# libnghttp2                1.57.0               h47da74e_0    intel
# libnsl                    2.0.1                hd590300_0    intel
# libpng                    1.6.39               h753d276_0    intel
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libsolv                   0.7.27               hfc55251_0    conda-forge
# libsqlite                 3.43.2               h2797004_0    intel
# libssh2                   1.11.0               h0841786_1    intel
# libstdcxx-ng              13.2.0               h7e041cc_2    intel
# libtiff                   4.6.0                ha9c0a0a_2    intel
# libuuid                   2.38.1               h0b41bf4_0    intel
# libwebp-base              1.3.2                hd590300_0    intel
# libxcb                    1.15                 h0b41bf4_1    intel
# libxml2                   2.11.5               h232c23b_1    intel
# libzlib                   1.2.13               hd590300_5    intel
# llvmlite                  0.40.1           py39h76e7cf5_0    intel
# lz4-c                     1.9.4                hcb278e6_0    intel
# lzo                       2.10              h516909a_1000    intel
# matplotlib-base           3.7.1            py39he190548_0    intel
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge
# menuinst                  2.0.2            py39hf3d152e_0    conda-forge
# mkl                       2024.0.0            intel_49630    intel
# mkl-dpcpp                 2024.0.0            intel_49630    intel
# mkl-service               2.4.0           py39h3539a15_40    intel
# mkl_fft                   1.3.6           py39h1d81ff8_61    intel
# mkl_random                1.2.2           py39h5a378b4_81    intel
# mkl_umath                 0.1.1           py39h2b1685c_91    intel
# munkres                   1.1.4              pyh9f0ad1d_0    intel
# ncurses                   6.4                  hcb278e6_0    intel
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# numba                     0.57.1           py39hb75a051_0    intel
# numba-dpex                0.21.4           py39hce084a9_0    intel
# numpy                     1.24.3           py39ha320b8e_5    intel
# numpy-base                1.24.3           py39hbac2b65_5    intel
# onemkl-sycl-blas          2024.0.0            intel_49630    intel
# onemkl-sycl-datafitting   2024.0.0            intel_49630    intel
# onemkl-sycl-dft           2024.0.0            intel_49630    intel
# onemkl-sycl-lapack        2024.0.0            intel_49630    intel
# onemkl-sycl-rng           2024.0.0            intel_49630    intel
# onemkl-sycl-sparse        2024.0.0            intel_49630    intel
# onemkl-sycl-stats         2024.0.0            intel_49630    intel
# onemkl-sycl-vm            2024.0.0            intel_49630    intel
# openjpeg                  2.5.0                h488ebb8_3    intel
# openssl                   3.2.1                hd590300_0    conda-forge
# packaging                 23.2               pyhd8ed1ab_0    intel
# pandas                    2.2.1            py39hddac248_0    conda-forge
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# patsy                     0.5.6              pyhd8ed1ab_0    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    10.0.1           py39had0adad_2    intel
# pip                       23.3               pyhd8ed1ab_0    intel
# platformdirs              3.11.0             pyhd8ed1ab_0    intel
# pluggy                    1.3.0              pyhd8ed1ab_0    intel
# pooch                     1.7.0              pyhd8ed1ab_4    intel
# prompt-toolkit            3.0.42             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.42               hd8ed1ab_0    conda-forge
# psutil                    5.9.8            py39hd1e30aa_0    conda-forge
# pthread-stubs             0.4               h36c2ea0_1002    intel
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.2              pyhd8ed1ab_0    conda-forge
# pybind11-abi              4                    hd8ed1ab_3    conda-forge
# pycosat                   0.6.6            py39hd1e30aa_0    intel
# pycparser                 2.21               pyhd8ed1ab_0    intel
# pygments                  2.17.2             pyhd8ed1ab_0    conda-forge
# pyopenssl                 23.2.0             pyhd8ed1ab_1    intel
# pyparsing                 3.1.1              pyhd8ed1ab_0    intel
# pysocks                   1.7.1              pyha2e5f31_6    intel
# python                    3.9.18               h4499717_0    intel
# python-dateutil           2.8.2              pyhd8ed1ab_0    intel
# python-tzdata             2023.3             pyhd8ed1ab_0    intel
# python_abi                3.9                      2_cp39    intel
# pytz                      2023.3.post1       pyhd8ed1ab_0    intel
# pyyaml                    6.0.1            py39hd1e30aa_1    intel
# pyzmq                     25.1.2           py39h8c080ef_0    conda-forge
# readline                  8.2                  h8228510_1    intel
# reproc                    14.2.4.post0         hd590300_1    conda-forge
# reproc-cpp                14.2.4.post0         h59595ed_1    conda-forge
# requests                  2.31.0             pyhd8ed1ab_0    intel
# ruamel.yaml               0.17.36          py39hd1e30aa_0    intel
# ruamel.yaml.clib          0.2.7            py39hd1e30aa_2    intel
# scikit-learn              1.3.1            py39ha22ef79_1    intel
# scikit-learn-intelex      2024.0.0        py39_intel_49530    intel
# scipy                     1.10.1           py39h6681978_6    intel
# seaborn                   0.13.2               hd8ed1ab_0    conda-forge
# seaborn-base              0.13.2             pyhd8ed1ab_0    conda-forge
# setuptools                68.2.2             pyhd8ed1ab_0    intel
# six                       1.16.0             pyh6c4a22f_0    intel
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# statsmodels               0.14.1           py39h44dd56e_0    conda-forge
# tbb                       2021.11.0           intel_49403    intel
# tbb4py                    2021.11.0       py39_intel_49403    intel
# threadpoolctl             3.2.0              pyha21a80b_0    intel
# tk                        8.6.13               h2797004_0    intel
# tornado                   6.4              py39hd1e30aa_0    conda-forge
# tqdm                      4.66.1             pyhd8ed1ab_0    intel
# traitlets                 5.14.1             pyhd8ed1ab_0    conda-forge
# typing-extensions         4.8.0                hd8ed1ab_0    intel
# typing_extensions         4.8.0              pyha770c72_0    intel
# tzdata                    2023c                h71feb2d_0    intel
# unicodedata2              15.0.0           py39hb9d737c_0    intel
# urllib3                   2.0.7              pyhd8ed1ab_0    intel
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# wheel                     0.41.2             pyhd8ed1ab_0    intel
# widgetsnbextension        4.0.10             pyhd8ed1ab_0    conda-forge
# xgboost                   1.7.3           0_gade498py39_25    intel
# xorg-libxau               1.0.11               hd590300_1    intel
# xorg-libxdmcp             1.1.3                h7f98852_1    intel
# xz                        5.2.6                h166bdaf_0    intel
# yaml                      0.2.5                h7f98852_2    intel
# yaml-cpp                  0.8.0                h59595ed_0    conda-forge
# zeromq                    4.3.5                h59595ed_0    conda-forge
# zipp                      3.17.0             pyhd8ed1ab_0    intel
# zstandard                 0.21.0           py39h6e5214e_1    intel
# zstd                      1.5.5                hfc55251_0    intel

# %%
#Each frame decoded and given emotions output. WITHOUT IPEX (Look from next cell for intended purpose)
import torch
import cv2
from PIL import Image
from transformers import AutoModelForImageClassification, BasicTokenizer
from torchvision.transforms import functional as F
import time

# Load the model
model_name = "dima806/facial_emotions_image_detection"
model = AutoModelForImageClassification.from_pretrained(model_name)

# Use a basic tokenizer
tokenizer = BasicTokenizer()

# Function to preprocess image
def preprocess_image(image):
    image = image.convert("RGB")
    image = image.resize((224, 224))  # Resize image to match model input size
    image = F.to_tensor(image)  # Convert PIL image to PyTorch tensor
    image = F.normalize(image, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize image
    return image.unsqueeze(0)  # Add batch dimension

# Function to perform facial emotion detection on an image
def predict_emotion(image):
    # Preprocess the image
    image = preprocess_image(image)
    
    # Perform inference
    with torch.no_grad():
        outputs = model(image)
        predicted_class_idx = torch.argmax(outputs.logits, dim=1).item()
    
    # Map class index to emotion label
    emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
    predicted_emotion = emotions[predicted_class_idx]
    
    return predicted_emotion

# Function to extract frames from video and perform facial emotion detection
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    seconds_count = 0

    print("AI is processing the emotions of the feeded video. Please wait...")
    print(f"Processing file: {video_path}\n")
    time.sleep(2)
    try:
        while(cap.isOpened()):
            ret, frame = cap.read()
            if ret == False:
                break
        
            # Convert frame to PIL image
            pil_image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        
        
            # Print predicted emotion 
            if frame_count % 300 == 0: #(For every 300 frames for 30fps video)
                # Perform facial emotion detection
                predicted_emotion = predict_emotion(pil_image)
                print(f"Frame {frame_count}: Predicted emotion - {predicted_emotion}")
        
            frame_count += 1
    except KeyboardInterrupt:
                print(f"\nUser interrupted the process. Run again...")
    except Exception as e:
                print(f"An error occurred: {e}")
    finally:
        cap.release()
        cv2.destroyAllWindows()

# Example usage
video_path = 'emotions.mp4'
process_video(video_path)

# %%
#For every 300 Frames. WITHOUT ipex optimization
import torch
import cv2
from PIL import Image
from transformers import AutoModelForImageClassification, BasicTokenizer
from torchvision.transforms import functional as F
import time

class EmotionDetector:
    def __init__(self, model_name):
        self.model = AutoModelForImageClassification.from_pretrained(model_name)
        self.tokenizer = BasicTokenizer()
    
    def preprocess_image(self, image):
        image = image.convert("RGB")
        image = image.resize((224, 224))  # Resize image to match model input size
        image = F.to_tensor(image)  # Convert PIL image to PyTorch tensor
        image = F.normalize(image, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize image
        return image.unsqueeze(0)  # Add batch dimension
    
    def predict_emotion(self, image):
        image = self.preprocess_image(image)
        with torch.no_grad():
            outputs = self.model(image)
            predicted_class_idx = torch.argmax(outputs.logits, dim=1).item()
        emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
        predicted_emotion = emotions[predicted_class_idx]
        return predicted_emotion

class VideoProcessor:
    def __init__(self, video_path, detector):
        self.video_path = video_path
        self.detector = detector
    
    def process_video(self):
        cap = cv2.VideoCapture(self.video_path)
        frame_count = 0
        seconds_count = 0
        print("❌ Without ipex optimization")
        print("AI is processing the emotions of the feeded video. Please wait...")
        print(f"Processing file: {self.video_path}\n")
        start_time = time.time()  # Start counting time
        try:
            while(cap.isOpened()):
                ret, frame = cap.read()
                if ret == False:
                    break
                pil_image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                if frame_count % 300 == 0:
                    predicted_emotion = self.detector.predict_emotion(pil_image)
                    print(f"{seconds_count}s | Frame {frame_count + 1}: Predicted emotion - {predicted_emotion}")
                    # Save the frame to disk
                    cv2.imwrite(f"emo/frame_{frame_count}.jpg", frame)
                    seconds_count += 10  # Increment seconds count by 10 (assuming 30 fps)
                frame_count += 1
        except KeyboardInterrupt:
            print(f"\nUser interrupted the process. Run again...")
        except Exception as e:
            print(f"An error occurred: {e}")
        finally:
            end_time = time.time()  # Stop counting time
            elapsed_time = end_time - start_time
            print(f"Total execution time: {elapsed_time} seconds")
            cap.release()

# Example usage
model_name = "dima806/facial_emotions_image_detection"
detector = EmotionDetector(model_name)
video_path = 'emotions.mp4'
processor = VideoProcessor(video_path, detector)
processor.process_video()
# Out:
# ❌ Without ipex optimization
# AI is processing the emotions of the feeded video. Please wait...
# Processing file: emotions.mp4
#
# 0s | Frame 1: Predicted emotion - Surprise
# 10s | Frame 301: Predicted emotion - Surprise
# 20s | Frame 601: Predicted emotion - Surprise
# 30s | Frame 901: Predicted emotion - Fear
# 40s | Frame 1201: Predicted emotion - Angry
# 50s | Frame 1501: Predicted emotion - Angry
# 60s | Frame 1801: Predicted emotion - Angry
# 70s | Frame 2101: Predicted emotion - Fear
# Total execution time: 3.0263562202453613 seconds

# %%
#For every 300 frames. WITH IPEX OPTIMIZED!
import torch
import cv2
from PIL import Image
from transformers import AutoModelForImageClassification, BasicTokenizer
from torchvision.transforms import functional as F
import time
import intel_extension_for_pytorch as ipex  # Import Ipex

class EmotionDetector:
    def __init__(self, model_name):
        # Optimize the model with Ipex, handling potential warnings
        self.model = ipex.optimize(AutoModelForImageClassification.from_pretrained(model_name))
        self.tokenizer = BasicTokenizer()

    def preprocess_image(self, image):
        # Preprocess image on CPU (avoiding PIL's 'to' method)
        cpu_image = image.convert("RGB").resize((224, 224))
        cpu_image = F.to_tensor(cpu_image)  # Convert to tensor on CPU
        cpu_image = F.normalize(cpu_image, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        return cpu_image.unsqueeze(0)  # Add batch dimension

    def predict_emotion(self, image):
        image = self.preprocess_image(image)
        with torch.no_grad():
            outputs = self.model(image)
            predicted_class_idx = torch.argmax(outputs.logits, dim=1).item()
        emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']
        predicted_emotion = emotions[predicted_class_idx]
        return predicted_emotion

class VideoProcessor:
    def __init__(self, video_path, detector):
        self.video_path = video_path
        self.detector = detector

    def process_video(self):
        cap = cv2.VideoCapture(self.video_path)
        frame_count = 0
        seconds_count = 0
        print("✅ With ipex optimization")
        print("AI is processing the emotions of the feeded video. Please wait...")
        print(f"Processing file: {self.video_path}\n")
        start_time = time.time()  # Start counting time
        try:
            while cap.isOpened():
                ret, frame = cap.read()
                if ret == False:
                    break
                pil_image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                if frame_count % 300 == 0:
                    predicted_emotion = self.detector.predict_emotion(pil_image)  # Process on CPU
                    print(f"{seconds_count}s | Frame {frame_count + 1}: Predicted emotion - {predicted_emotion}")
                    # Save the frame to disk
                    cv2.imwrite(f"emo/frame_{frame_count}.jpg", frame)
                    seconds_count += 10  # Increment seconds count by 10 (assuming 30 fps)
                frame_count += 1
        except KeyboardInterrupt:
            print(f"\nUser interrupted the process. Run again...")
        except Exception as e:
            print(f"An error occurred: {e}")
        finally:
            end_time = time.time()  # Stop counting time
            elapsed_time = end_time - start_time
            print(f"Total execution time: {elapsed_time} seconds")
            cap.release()

# Example usage
model_name = "dima806/facial_emotions_image_detection"
detector = EmotionDetector(model_name)
video_path = 'emotions.mp4'
processor = VideoProcessor(video_path, detector)
processor.process_video()
# Out:
# ✅ With ipex optimization
# AI is processing the emotions of the feeded video. Please wait...
# Processing file: emotions.mp4
#
# 0s | Frame 1: Predicted emotion - Surprise
# 10s | Frame 301: Predicted emotion - Surprise
# 20s | Frame 601: Predicted emotion - Surprise
# 30s | Frame 901: Predicted emotion - Fear
# 40s | Frame 1201: Predicted emotion - Angry
# 50s | Frame 1501: Predicted emotion - Angry
# 60s | Frame 1801: Predicted emotion - Angry
# 70s | Frame 2101: Predicted emotion - Fear
# Total execution time: 2.9871420860290527 seconds
